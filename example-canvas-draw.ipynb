# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
x = np.linspace(0, 10, 100)

# %%
y1 = np.sin(x)

# %%
fig, ax = plt.subplots()
ax.plot(x, y1);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.canvas.draw()

# %%
plt.close(fig)

# %%
y2 = np.cos(x)

# %%
fig, ax = plt.subplots()
ax.plot(x, y1)
ax.plot(x, y2);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.canvas.draw()

# %%
plt.close(fig)
